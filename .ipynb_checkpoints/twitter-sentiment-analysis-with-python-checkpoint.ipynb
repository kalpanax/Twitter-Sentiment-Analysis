# %% [markdown]
# # <span style='font-family:montserrat;color:#0A043C'>Twitter Sentiment Analysis</span>

# %% [markdown]
# ### <span style='font-family:montserrat;color:#C84B31'>Project by Kalpana Kashyap</span>

# %%
# utilities
import numpy as np
import pandas as pd
# plotting
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# visualization
import re
from textblob import TextBlob
from wordcloud import WordCloud
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# Importing the dataset
df = pd.read_csv('tweets_data.csv')
df.head()
# Out:
#    Unnamed: 0  id  label                                              tweet
# 0           0   1      0   @user when a father is dysfunctional and is s...
# 1           1   2      0  @user @user thanks for #lyft credit i can't us...
# 2           2   3      0                                bihday your majesty
# 3           3   4      0  #model   i love u take with u all the time in ...
# 4           4   5      0             factsguide: society now    #motivation

# %%
# remove unnecessary columns
df = df.drop(labels=['Unnamed: 0', 'id', 'label'],axis=1)

# %%
df.head()
# Out:
#                                                tweet
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
df.shape
# Out:
# (31962, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweet   31962 non-null  object
# dtypes: object(1)
# memory usage: 249.8+ KB

# %%
df.shape
# Out:
# (31962, 1)

# %%
# as data is very big, it will take a lot of time to do analysis so I have sliced it to only 500 tweets
# method is same for any number of tweets
df = df[:500]

# %%
df.shape
# Out:
# (500, 1)

# %%
# if we need to find tweets of a particular keyword such as Alexa, Amazon, Marvel, Bill Gates, etc
# df = df[df.tweet.str.contains(‘alexa’)]

# %%
# clean data
def clean_tweet(text):
    text = re.sub(r'@[a-zA-Z0-9]+','', text) # remove @
    text = re.sub(r'#','', text) # remove # hanshtag
    text = re.sub(r'RT[\s]+','', text) # remove RT
    text = re.sub(r'https?:\/\/\S+','', text) # remove hyperlinks
    return text

# %%
df['clean_tweet'] = df ['tweet'].apply(clean_tweet)

# %%
df.head()
# Out:
#                                                tweet  \
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0    when a father is dysfunctional and is so sel...
# 1    thanks for lyft credit i can't use cause the...
# 2                                bihday your majesty
# 3  model   i love u take with u all the time in u...
# 4              factsguide: society now    motivation

# %%
# to check null values in col
df.isnull().sum()
# Out:
# tweet          0
# clean_tweet    0
# dtype: int64

# %%
# to get subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
# to get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['subjectivity'] = df['tweet'].apply(getSubjectivity)
df['polarity'] = df['tweet'].apply(getPolarity)

# %%
df.head()
# Out:
#                                                tweet  \
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation
#
#                                          clean_tweet  subjectivity  polarity
# 0    when a father is dysfunctional and is so sel...           1.0 -0.500000
# 1    thanks for lyft credit i can't use cause the...           0.2  0.200000
# 2                                bihday your majesty           0.0  0.000000
# 3  model   i love u take with u all the time in u...           0.6  0.976562
# 4              factsguide: society now    motivation           0.0  0.000000

# %%
# displaying wordcloud
all_words = " ".join([sentence for sentence in df['clean_tweet']])
wordcloud = WordCloud(width=800,height=500,random_state=42,max_font_size=80).generate(all_words)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# compute the negative, neautral and positive analysis
def sent_analysis(score):
    if score<0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
df['analysis'] = df['polarity'].apply(sent_analysis)

# %%
df.head()
# Out:
#                                                tweet  \
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation
#
#                                          clean_tweet  subjectivity  polarity  \
# 0    when a father is dysfunctional and is so sel...           1.0 -0.500000
# 1    thanks for lyft credit i can't use cause the...           0.2  0.200000
# 2                                bihday your majesty           0.0  0.000000
# 3  model   i love u take with u all the time in u...           0.6  0.976562
# 4              factsguide: society now    motivation           0.0  0.000000
#
#    analysis
# 0  Negative
# 1  Positive
# 2   Neutral
# 3  Positive
# 4   Neutral

# %%
# compute the negative, neautral and positive analysis
def value_analysis(text):
    if text == 'Negative':
        return -1
    elif text == 'Neutral':
        return 0
    else:
        return 1

# %%
df['value'] = df['analysis'].apply(value_analysis)

# %%
df.head()
# Out:
#                                                tweet  \
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation
#
#                                          clean_tweet  subjectivity  polarity  \
# 0    when a father is dysfunctional and is so sel...           1.0 -0.500000
# 1    thanks for lyft credit i can't use cause the...           0.2  0.200000
# 2                                bihday your majesty           0.0  0.000000
# 3  model   i love u take with u all the time in u...           0.6  0.976562
# 4              factsguide: society now    motivation           0.0  0.000000
#
#    analysis  value
# 0  Negative     -1
# 1  Positive      1
# 2   Neutral      0
# 3  Positive      1
# 4   Neutral      0

# %%
# displaying wordcloud for positive tweets i.e Analysis == Positive
all_positive = " ".join([sentence for sentence in df['clean_tweet'][df['analysis']=='Positive']])
wordcloud = WordCloud(width=800,height=500,random_state=42,max_font_size=80).generate(all_positive)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# displaying wordcloud for negative tweets i.e Analysis == negative
all_negative = " ".join([sentence for sentence in df['clean_tweet'][df['analysis']=='Negative']])
wordcloud = WordCloud(width=800,height=500,random_state=42,max_font_size=80).generate(all_negative)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# displaying wordcloud for neutral tweets i.e Analysis == neutral
all_neutral = " ".join([sentence for sentence in df['clean_tweet'][df['analysis']=='Neutral']])
wordcloud = WordCloud(width=800,height=500,random_state=42,max_font_size=80).generate(all_neutral)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# print positive tweets by popularity
j=1
popularity_df = df.sort_values(by=['polarity'])
for i in range(0, popularity_df.shape[0]):
    if(popularity_df['analysis'][i]=='Positive'):
        print(str(j) + ') ' + popularity_df['clean_tweet'][i] + "\n")
        j=j+1
# Out:
# 1)   thanks for lyft credit i can't use cause they don't offer wheelchair vans in pdx.    disapointed getthanked
#
# 2) model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# 3) [2/2] huge fan fare and big talking before they leave. chaos and pay disputes when they get there. allshowandnogo
#
# 4) we won!!! love the land!!! allin cavs champions cleveland clevelandcavaliers  â¦
#
# 5)    welcome here !  i'm   it's so gr8 !
#
# 6) i am thankful for having a paner. thankful positive
#
# 7) euro2016 people blaming ha for conceded goal was it fat rooney who gave away free kick knowing bale can hit them from there.
#
# 8) product of the day: happy man wine tool  who's   it's the weekend? time to open up &amp; drink up!
#
# 9) beautiful sign by vendor 80 for $45.00!! upsideofflorida shopalyssas   love
#
# 10)   all smiles when media is   !! ðð pressconference in antalya turkey ! sunday throwback  love! ððâ¤ï¸
#
# 11) we had a great panel on the mediatization of the public service   ica16
#
# 12) happy father's day  ðððð
#
# 13) 50 people went to nightclub to have a good night and 1 man's actions means those people are lost to their families forever riporlando
#
# 14) i have never had a chance to vote for a presidential candidate i was excited about and this cycle looks to be no different.
#
# 15) taylorswift1989   bull up: you will dominate your bull and you will direct it whatever you want it to do. w
#
# 16)  once more only one word tells it all: photoshop.  enoughisenough dontphotoshopeverything wheresallthenaturalphotos
#
# 17) i am thankful for sunshine. thankful positive
#
# 18) there is life after social networking. embrace each day. be
#
# 19) lovely echeveria bloomsflowers grow gardening iphonesia bliss blooms basilicabotanica
#
# 20) i am amazing. i_am positive affirmation
#
# 21) model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# 22) the best pa about life is knowing who you are! ðâï¸ð¼ð»  â¦
#
# 23) abc2020 getting ready 2 remove the victums frm pulseclub prayfororlando
#
# 24) for her bihday we got her a nose job   ðð¶ððð    bihday petunia we love you ð
#
# 25) off to concelebrate at the albanpilgrimage for the first time.
#
# 26) thank you! ðð super love it! â¤ï¸ zpamdelacruz   wedding @ dolores, capas tarlac.
#
# 27)  lets fight against  love peace
#
# 28)  happy fatherâs day, mr. rayos video   fathers day rayos world hotvideo videos
#
# 29) happy at work conference: right' mindset leads to culture-of-development organizations    work mindset
#
# 30) we are ready to dance roar preschoolers   students proudâ¦
#
# 31)  i am so jealous of you right now.... chatiado
#
# 32) i'm sure they are just as happy.... ðð½ðð½ðð½   hour
#
# 33) ð©the white establishment can't have blk folx running around loving themselves and promoting our greatness
#
# 34) good morning! the journey begins! ððð»ð³   travel yeah thejourneybegins helloâ¦
#
# 35) our new brochures have arrived! how exciting!! aworks solutions
#
# 36) so much stuff happening in florida! first orlando shooting and now disneygatorattack on a two year old kidð¥ð
#
# 37)  ferrari will do itðªð¼ for the sake of the championship. this gp is clearly a turning point rb, ferrari,mercs...ð
#
# 38) aced my first test!   proud
#
#
# 203) lawofattraction for healing loa   be healthy   well idwp !
#
# 204) training in new employee's is fun. newblood
#
# 205)   first bihday to our puppy eloise sweetbabins dog growingup cute bihdaygirl
#
# 206)     - 5,000 pigs burn alive in saskatchewan barn fire (video)
#
# 207)   you'll never convince me that americans have the right to bear these.   prayfororlando guncontrol
#
# 208) with my beautiful ladies!!! is a blessing to know them !!ó¾¬ó¾¬. smile   lovethemâ¦
#
# 209) at  for 'an audience with duane henry ' ....should be very insightful
#
# 210) how creepy awesome are these baboons climbing the fire escape like humans on    summev zoo
#
# 211) use the power of your mind to heal your body!    altwaystoheal healthy is  !!
#
# 212)   we don't laugh because we're happy... we're   because we laugh. - william james.  xtra
#
# 213) have a happy sunday everyone! i think today is going to be a good day :) positivevibes   sunshine sunday
#
# 214)   because i am happy! ðð happiness minions
#
# 215) no elder scrolls for many years?!! wah wah    bethesda e3 e32016
#
# 216) very   to work with russell.beckwith soon staytuned ð¸: my friend lyle!! tapfoags ..â¦
#
# 217) sharing ice cream sun love outdoors picnic summer family daughter father desse icecream
#
# 218) cleaning ze house and zoing ziy laundry. ã i'm finally free from fever and colds. â©__â©i'm happy! cleaning laundryday
#
# 219) 2 new listings are up!   ebay     woohoo sell selling buy shop shopping
#
# 220) i am thankful for my challenges. thankful positive
#
# 221)  biherism absolutely originated in hateful  bigotry altright hatred of our african american potus theresistance
#
# 222) fab &amp; interesting day at eacbpm. now dash to a quiet place to dial into iiba emea region meeting busy   :)
#
# 223) we'll back going to tacloban now! see ya later!ó¾µâ¤   great â traveling to tacloban city from catbalogan
#
# 224)   sunday to you all ð photo by   model urbex topless tits mono retweet  sexy heels ace
#
# 225) yayyyy my friend got married today ð°ð°ð°ð«ð« congratulations guys. â¤ï¸â¤ï¸  shegotmarried  â¦
#
# 226) model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# 227) if lewis remains perfect, the rangers announcers are gonna stroke out.
#
# 228) chris is so   to be back to soccer after missing most of spring season with a brokenâ¦
#
# 229) it's a beautiful day..... sun   fun beachpark @ beach park
#
# 230) the big screen is being fitted right now   euros2016
#
# 231) not all love stories are happy ending.  anime love story not   ending like4likeâ¦
#
# 232) poet   bull up: you will dominate your bull and you will direct it whatever you want it to do. when you sta
#
# 233) i am tranquil. i_am positive affirmation
#
# 234)  is that the name of any upcoming new track? ðð   2pm kpop
#
# 235) best essentialoils for anxiety !!     healthy   peace !!  altwaystoheal !!
#
# 236)     wow some people's children have nothing better to do then insult people on twitter .  .
#
# 237) ð¸ð»ð¼ððº snapchat: gaby_china20  love girl snapchat   flowers instasmile instaloveâ¦
#
# 238) i am brilliant. i_am positive affirmation
#
# 239)   true :/ niggas dont go looking for apaments they go look at shoes and jewelry
#
# 240) safe ways to heal your acne!!    altwaystoheal healthy   healing!!
#
# 241) msgapparelstoday    u r so special 4 us   father day
#
# 242) my forever bestie ð karaoke friends friendship love nofilter instacool instagood  â¦
#
# 243)  absolutely love this place. fantastic welcome from carlos, receptionist. 5th time here. room request granted as usual. 318
#
# 244)  â us retail sales control group likely rose 0.2% m/m in may â danske bank   blog silver gold forex
#
# 245) happy fathers day. you are love of my life &amp;the best father in the world. â¤ï¸ð  fathersday love
#
# 246)   ? funny ? or simply so truestory :)
#
# 247) happy bihday to me!... brithday day holidays  monday menmodelsâ¦
#
# 248) new season of oitnb stas tonight ðð¼   oitnbseason4 ð¬ð¬
#
# 249)   excited to be on the other side of the cuain for once tonight. looking forward to seeing  on broadwayâ¦
#
# 250) i am impressive. i_am positive affirmation
#
# 251) our view from the 27th floor! :) nyc newyorkcity myview   girl wine fridaynightâ¦
#
# 252) amen!! truth. always. &lt;3 &lt;3  love     blessed
#
# 253)  and the stamford kid got 6 months for rape.but that wasn't boredom...it was 20 minutes of action.   .
#
# 254) lets colorized your life w/ rainbow danian love colour rainbow   @ depok
#
# 255) hi teddy corpuz... rocksteddy band enjoy idol   omg ððððððð
#
# 256)  wow, what a great daughter you are! to send that to your father right before father's day. cheapshot lowblow   shame
#
# 257) 6 reasons to be happyâ¦when your kid is mid-tantrum    parenting tantrum toddler calm mindfulness   strong
#
# 258) i am truthful. i_am positive affirmation
#
# 259) yup siri on macos wwdc2016 - :) woot! next did they work on her listening skills?
#
# 260)    thats the problem, only one police officer. you need more, with bigger guns and perhaps one tank with soldiersâ¦

# %%
# print negative tweets by popularity
j=1
popularity_df = df.sort_values(by=['polarity'])
for i in range(0, popularity_df.shape[0]):
    if(popularity_df['analysis'][i]=='Negative'):
        print(str(j) + ') ' + popularity_df['clean_tweet'][i] + "\n")
        j=j+1
# Out:
# 1)   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   run
#
# 2) the next school year is the year for exams.ð¯ can't think about that ð­ school exams   hate imagine actorslife revolutionschool girl
#
# 3)  â ireland consumer price index (mom) climbed from previous 0.2% to 0.5% in may   blog silver gold forex
#
# 4) we are so selfish. orlando standwithorlando pulseshooting orlandoshooting biggerproblems selfish heabreaking   values love
#
# 5) sad little dude..   badday coneofshame cats pissed funny laughs
#
# 6) it was a hard monday due to cloudy weather. disabling oxygen production for today. goodnight badmonday
#
# 7) it's unbelievable that in the 21st century we'd need something like this. again. neverump  xenophobia
#
# 8) yup, being a knicks fan is hard, so its easier to just be an nba fan when the playoffs roll around ð
#
# 9) whenever im   and something goes wrong  |
#
# 10) you've really hu my feelings :(
#
# 11) carrying a gun wouldn't of helped if you can't take it in with you. gun control won't stop the black market! terrorism will get worse!
#
# 12) there are some truly sick ppl out there.
#
# 13)  i'm not interested in a linguistics that doesn't address race &amp; . racism is about power. raciolinguistics bringsâ¦
#
# 14)  why not  mocked obama for being black.      brexit
#
# 15) toradora anime animeedit i made it.   breakups alone lonely
#
# 16) cotd   polar bear climb racing: angry polar bear climb racing, the polar bear living in cold places looking
#
# 17)    gets him angry.  a muslim assassinating 50 not so much.
#
# 18) sad in the branches itâs just rainy day writing tears are flying birds   haiku 3lines micropoetry
#
# 19) anyone know the date our doj and fbi became corrupted? emailgate hillary2016 shameful disgraceful ridiculous
#
# 20) stupidity makes me more   than even negligence.why put sachintendulkar a installation if u were going to take it off?
#
# 21)   i've had pretty bad bihday weeks before, but so far this is the worst ever. ð bihdayweeksucks bithday27   tâ¦
#
# 22) just found out  is at  after i'd been exclaiming to  how gr8 blain's hair was the other nite.   ð­
#
# 23) be   n healthy freedom from effo in the present merely means that there has been effo stored up in the past. â theodore rooseveltâ¦
#
# 24) yes it's  when you call michelleobama a gorilla because racists have long thought of black people as no betâ¦
#
# 25) when the internet is broken so you can't watch netflix. mochithepug puglife
#
# 26)    and she will do just that....then what..business as usual.
#
# 27) hbd to this dick suckin tequila lovin slut, i wouldnt want u any other way ðð   justalillate butstillontime
#
# 28) sad to hear the announcers say that "it may have moved the player to one or two out of the lead" whoknows!
#
# 29)  terrorist = constitutional rights?  this is just another excuse by republicans to appease the nra with no gun control measures. !
#
# 30)   very sad,  what happened?
#
# 31) everyone is everything   sad together alone up down fine dandy lonely exuberant depressed halffull halfempty
#
# 32) angry birds stella bad princess   birds stella bad princess birdsstellabadprincess.  time post: wedâ¦
#
# 33) devastating news.  my hea goes out to the victims and their families.  orlando heabreaking
#
# 34) argentina2015   attack bull game 3d: do you really think that his head was empty around the city. each side
#
# 35) building   polar bear climb racing: angry polar bear climb racing, the polar bear living in cold places loo
#
# 36) my hea is with orlando right now. i truly cannot imagine. could have easily happened anywhere. :(
#
# 37) it seems like the only place with action here is montreal :(
#
# 38)    this shows truly how bad brisbane are
#
# 39) this really takes the piss. i'm so angry. just goes to show who is valued and who isn't. you complete and utter moron.
#
# 40)  take out the trash america...  - i voted against hate - i voted against  - i voted against  - i votâ¦
#
# 41) "there's a reason why two people stay together, they give each other something nobody else can." hopelly greats day
#
# 42) we lost another member of our family yesterday:-( gutted   rosie
#
# 43) watch fancy tails's vine "mad mad   teeth bite pissed dog   biting dogbite dogtreat
#
# 44)    on dallas shooting "the video you're about to see is disturbing, so viewer discretion" then they play it in a loop oveâ¦
#
# 45) stereotyping prejudice  offer no hope or solutions but create the same old repetitive hate conflictâ¦
#
# 46)   anyone playing voez? kinda in love with this game ððð game   gaming girlgamer voez
#
# 47)  im half boy half man.... so im dumb too??   ð¢ð
#
# 48) i heard him say that, he was trying to lock the shooter in,  but kept other patrons from getting out!
#
# 49) twinklatinboys - na: slut snapshot hot nasty naughty sexy horny shy porn nude   kinky xxx y...
#
# 50)   stuck in athens instead of santorini because  said it was to windy to land! shocking service on every level since!â¦
#
# 51) first months, then weeks, now it's only days till the beginning of the end of  i am both   and sad at the same time.ðð¢
#
# 52) blackpool   attack bull game 3d: do you really think that his head was empty around the city. each side is
#
# 53) i'm sad. my aunt passed away. she was 96.   funeral
#
# 54) 7 horribly  ads from 2016 that made us cringe
#
# 55) hahaha.. this is me last friday   &amp; weird
#
# 56) watching the  leadership embrace &amp; kiss donald's ass is pathetic &amp;  . this is now the  pay. a pay of racism &amp; hate. ripgop
#
# 57)   theverdict is in; i'm an idiot country rock bluegrass beatles love pop   romance
#
# 58) i hate like 90% of my family.... i was really born into a big ass toxic bomb! mother fuckers don't give a fuck about me cuz i got money
#
# 59) my monday is so empty without the bachelorette ð©ð¹ð· thebachelorette   empty nowine
#
# 60)   my sister ain't even know i was watching her argue with the nigga ððð was waiting for him too say the wrong shit
#
# 61) payintheusa   polar bear climb racing: angry polar bear climb racing, the polar bear living in cold place
#
# 62)  â oil turns flat to $50.40, eyeing eia inventory data for fuher direction   blog silver gold forex
#
# 63)   poor tiggy ð¢ and a little bit cheeky jax &amp;   ð soa throwbackthursday
#
# 64) all these tragedies in america first with the killing of christinagrimmie and now orlando america is not a safe place to be today!
#
# 65)  â brexit angst a factor helping drive down interest rates in germany and japan - bbh   blog silver gold â¦
#
# 66) u can hold a man down for years ...and watch him change on u over some hear say..    no loyalty.. no...
#
# 67) angry birds il film download ita â 720p hdtc (2016)    birds download film il ita
#
# 68) fo woh officer in viral arrest video was ârude not racistâ: chief  crime officerâ¦
#
# 69) ryderrideu - see you c2c and cum together: snapshot young shy kinky wet porn hot   xxx horny s...
#
# 70) this is a shockingly   and increasingly violent world we live in and the uk has gun control laws. i feel for the mp's family &amp; friends
#
# 71) aiel aielmaharashtra rude customer care executive makes me want to switch my loyalty to another provider.   irritated
#
# 72) are you black &amp; feel like the  are stomping on you? â¦  retweet tampa miamiâ¦

# %%
# plot the polarity and subjectivity
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
    plt.scatter(df['polarity'][i],df['subjectivity'][i],color='Blue')
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
sns.heatmap(df[['subjectivity', 'polarity']].corr(), annot=True)
plt.show()

# %%
# percentage of positive tweets
positive_tweets = df[df.analysis == 'Positive']
positive_tweets = positive_tweets['clean_tweet']

positive_percent = round((positive_tweets.shape[0] / df.shape[0]) * 100, 1)
print('Percentage of Positive tweets is: ' + str(positive_percent) + '%')
# Out:
# Percentage of Positive tweets is: 52.0%

# %%
# percentage of negative tweets
negative_tweets = df[df.analysis == 'Negative']
negative_tweets = negative_tweets['clean_tweet']

negative_percent = round((negative_tweets.shape[0] / df.shape[0]) * 100, 1)
print('Percentage of Positive tweets is: ' + str(negative_percent) + '%')
# Out:
# Percentage of Positive tweets is: 14.4%

# %%
# percentage of neutral tweets
neutral_tweets = df[df.analysis == 'Neutral']
neutral_tweets = neutral_tweets['clean_tweet']

neutral_percent = round((neutral_tweets.shape[0] / df.shape[0]) * 100, 1)
print('Percentage of Positive tweets is: ' + str(neutral_percent) + '%')
# Out:
# Percentage of Positive tweets is: 33.6%

# %%
# numbers to positive, negative and neutral tweets
df['analysis'].value_counts()
# Out:
# Positive    260
# Neutral     168
# Negative     72
# Name: analysis, dtype: int64

# %%
# value counts and visualization
df['analysis'].value_counts()
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['analysis'].value_counts().plot(kind='bar')
plt.show()

# %%
# plt.figure(figsize = (15, 5))
# plt.subplot(1,2,1)
# sns.countplot(df['analysis'])
# plt.show()
